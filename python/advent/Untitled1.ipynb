# %%
import p23pure

# %%
bots = p23pure.get_bots()
len(bots)
# Out:
# 1000

# %%
p23pure.calc2(bots)
# Out:
# Trying with bounds =1/1001, probe=501, |Tried|=0
# FINDing xs=[-164366478, 104068978], ys=[-104069375, 164366081], zs=[-82992136, 185443320], dist=268435456, fc=501
# FINDing xs=[104068978, 238286706], ys=[-104069375, 30148353], zs=[-82992136, 51225592], dist=134217728, fc=501
# FINDing xs=[104068978, 171177842], ys=[30148353, 97257217], zs=[51225592, 118334456], dist=67108864, fc=501
# FINDing xs=[104068978, 137623410], ys=[30148353, 63702785], zs=[51225592, 84780024], dist=33554432, fc=501
# FINDing xs=[104068978, 120846194], ys=[30148353, 46925569], zs=[51225592, 68002808], dist=16777216, fc=501
# FINDing xs=[104068978, 120846194], ys=[30148353, 46925569], zs=[84780024, 101557240], dist=16777216, fc=501
# FINDing xs=[104068978, 120846194], ys=[63702785, 80480001], zs=[51225592, 68002808], dist=16777216, fc=501
# FINDing xs=[137623410, 154400626], ys=[30148353, 46925569], zs=[51225592, 68002808], dist=16777216, fc=501
# ...
