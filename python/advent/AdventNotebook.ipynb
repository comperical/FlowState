# %%
import sys
import time
import importlib
from collections import deque
from IPython.display import Image

sys.path.append("..")
import utility as U

# %%
pcode = "p23b"
pmod = importlib.import_module(pcode)

# %%
pmachine = pmod.PMachine()
#pmachine.test_code = 'A'

# %%
imgpath = U.create_diagram(pmachine, pcode, keepgv=True)
Image(imgpath)
# Out:
# Writing to path: /userdata/external/FlowState/diagram/advent/p23b.gv
# Wrote GV output to path /userdata/external/FlowState/diagram/advent/p23b.gv
# dot /userdata/external/FlowState/diagram/advent/p23b.gv -Tpng > /userdata/external/FlowState/diagram/advent/p23b.png

# %%
#pmod.run_tests()

# %%
pmachine.run2_completion()
#pmachine.run2_step_count(100)
# Out:
# searching with bounds=1/1000, attempt=500
# Successful search at attempted_count=500, best point is (3405682, 30148353, 51225592), count is 669, mdist=84779627
# searching with bounds=500/1000, attempt=750
# Successful search at attempted_count=750, best point is (20162811, 33294080, 15252294), count is 750, mdist=68709185
# searching with bounds=750/1000, attempt=875
# Successful search at attempted_count=875, best point is (27456271, 32245504, 26059767), count is 876, mdist=85761542
# searching with bounds=875/1000, attempt=937
# Successful search at attempted_count=937, best point is (33931870, 28051200, 23778473), count is 937, mdist=85761543
# searching with bounds=937/1000, attempt=968
# Successful search at attempted_count=968, best point is (34574429, 27408640, 23778473), count is 968, mdist=85761542
# searching with bounds=968/1000, attempt=984
# Search failed at attempted_count=984
# searching with bounds=968/984, attempt=976
# Search failed at attempted_count=976
# searching with bounds=968/976, attempt=972
# Search failed at attempted_count=972
# searching with bounds=968/972, attempt=970
# Successful search at attempted_count=970, best point is (34574432, 27408638, 23778473), count is 970, mdist=85761543
# searching with bounds=970/972, attempt=971
# Search failed at attempted_count=971

# %%
pmachine.get_result()
# Out:
# 85761543

# %%
#pmod.reddit_wrap()
#bots = pmod.get_bots()

# %%
#len(bots)

# %%
#pmod.count_for_point(bots,164366478, 104069375, 82992136, 536870912)
