# %%
import sys
import time
import importlib
from collections import deque
from IPython.display import Image

sys.path.append("..")
import utility as U

# %%
pcode = "p25a"
pmod = importlib.import_module(pcode)

# %%
pmachine = pmod.PMachine()

# %%
imgpath = U.create_diagram(pmachine, pcode, keepgv=True)
Image(imgpath)
# Out:
# Writing to path: /userdata/external/FlowState/diagram/advent/p25a.gv
# Wrote GV output to path /userdata/external/FlowState/diagram/advent/p25a.gv
# dot /userdata/external/FlowState/diagram/advent/p25a.gv -Tpng > /userdata/external/FlowState/diagram/advent/p25a.png

# %%
pmod.run_tests()
# Out:
# For tcode A, expected 2, result is 2... success
# For tcode B, expected 4, result is 4... success
# For tcode C, expected 3, result is 3... success
# For tcode D, expected 8, result is 8... success

# %%
pmachine.run2_completion()

# %%
pmachine.get_result()
# Out:
# 310
