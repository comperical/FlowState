# %%
import sys
import importlib
from IPython.display import Image

sys.path.append("..")
import utility as U

# %%
pcode = "p03b"
pmod = importlib.import_module(pcode)

# %%
pmachine = pmod.PMachine()

# %%
imgpath = U.create_diagram(pmachine, pcode, keepgv=True)
Image(imgpath)
# Out:
# Writing to path: /userdata/external/FlowState/diagram/advent/p03b.gv
# Wrote GV output to path /userdata/external/FlowState/diagram/advent/p03b.gv
# dot /userdata/external/FlowState/diagram/advent/p03b.gv -Tpng > /userdata/external/FlowState/diagram/advent/p03b.png

# %%
pmachine.run2_completion()

# %%
pmachine.get_result()
# Out:
# {1124}
# 1124
