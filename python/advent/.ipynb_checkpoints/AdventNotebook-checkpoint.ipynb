# %%
import sys
import time
import importlib
from collections import deque
from IPython.display import Image

sys.path.append("..")
import utility as U

# %%
pcode = "p15a"
pmod = importlib.import_module(pcode)

# %%
pmachine = pmod.PMachine()

# %%
imgpath = U.create_diagram(pmachine, pcode, keepgv=True)
Image(imgpath)
# Out:
# Writing to path: /userdata/external/FlowState/diagram/advent/p15b.gv
# Wrote GV output to path /userdata/external/FlowState/diagram/advent/p15b.gv
# dot /userdata/external/FlowState/diagram/advent/p15b.gv -Tpng > /userdata/external/FlowState/diagram/advent/p15b.png

# %%
pmod.run_tests()
# Out:
# Read input data, have 27 walls and 6 creatures
# Calculated initial elf count=2 for testcode=B
# Read input data, have 27 walls and 6 creatures
# Status is: ['G200', 'G131', 'G59', 'G200']
# For boost=0, have 0 survivors, vs 2 initial
# Read input data, have 27 walls and 6 creatures
# Status is: ['G200', 'G108', 'G12', 'G200']
# For boost=1, have 0 survivors, vs 2 initial
# Read input data, have 27 walls and 6 creatures
# Status is: ['G200', 'G60', 'G185']
# For boost=2, have 0 survivors, vs 2 initial
# Read input data, have 27 walls and 6 creatures
# Status is: ['G200', 'G176']
# For boost=3, have 0 survivors, vs 2 initial
# Read input data, have 27 walls and 6 creatures
# Status is: ['G200', 'G102']
# For boost=4, have 0 survivors, vs 2 initial
# Read input data, have 27 walls and 6 creatures
# Status is: ['G32', 'G200']
# For boost=5, have 0 survivors, vs 2 initial
# Read input data, have 27 walls and 6 creatures
# Status is: ['G137']
# For boost=6, have 0 survivors, vs 2 initial
# Read input data, have 27 walls and 6 creatures
# Status is: ['E8']
# For boost=7, have 1 survivors, vs 2 initial
# Read input data, have 27 walls and 6 creatures
# Status is: ['E41']
# For boost=8, have 1 survivors, vs 2 initial
# Read input data, have 27 walls and 6 creatures
# Status is: ['E98']
# For boost=9, have 1 survivors, vs 2 initial
# Read input data, have 27 walls and 6 creatures
# Status is: ['E125']
# For boost=10, have 1 survivors, vs 2 initial
# Read input data, have 27 walls and 6 creatures
# Status is: ['E152']
# For boost=11, have 1 survivors, vs 2 initial
# Read input data, have 27 walls and 6 creatures
# Status is: ['E158', 'E14']
# For boost=12, have 2 survivors, vs 2 initial
# Test successful for TC=B
# Read input data, have 29 walls and 9 creatures
# Calculated initial elf count=6 for testcode=D
# Read input data, have 29 walls and 9 creatures
# Status is: ['E164', 'E197', 'E200', 'E98', 'E200']
# For boost=0, have 5 survivors, vs 6 initial
# Read input data, have 29 walls and 9 creatures
# Status is: ['E200', 'E23', 'E200', 'E125', 'E200', 'E200']
# For boost=1, have 6 survivors, vs 6 initial
# Test successful for TC=D
# Read input data, have 28 walls and 7 creatures
# Calculated initial elf count=2 for testcode=E
# Read input data, have 28 walls and 7 creatures
# Status is: ['G200', 'G98', 'G200', 'G95', 'G200']
# For boost=0, have 0 survivors, vs 2 initial
# Read input data, have 28 walls and 7 creatures
# Status is: ['G200', 'G64', 'G200', 'G60', 'G200']
# For boost=1, have 0 survivors, vs 2 initial
# Read input data, have 28 walls and 7 creatures
# Status is: ['G200', 'G30', 'G200', 'G25', 'G200']
# For boost=2, have 0 survivors, vs 2 initial
# Read input data, have 28 walls and 7 creatures
# Status is: ['G200', 'G200', 'G188']
# For boost=3, have 0 survivors, vs 2 initial
# Read input data, have 28 walls and 7 creatures
# Status is: ['G165', 'G200', 'G130']
# For boost=4, have 0 survivors, vs 2 initial
# Read input data, have 28 walls and 7 creatures
# Status is: ['G128', 'G200', 'G72']
# For boost=5, have 0 survivors, vs 2 initial
# Read input data, have 28 walls and 7 creatures
# Status is: ['G101', 'G200', 'G29']
# For boost=6, have 0 survivors, vs 2 initial
# Read input data, have 28 walls and 7 creatures
# Status is: ['G130', 'G60']
# For boost=7, have 0 survivors, vs 2 initial
# Read input data, have 28 walls and 7 creatures
# Status is: ['G123', 'G2']
# For boost=8, have 0 survivors, vs 2 initial
# Read input data, have 28 walls and 7 creatures
# Status is: ['E8']
# For boost=9, have 1 survivors, vs 2 initial
# Read input data, have 28 walls and 7 creatures
# Status is: ['E32']
# For boost=10, have 1 survivors, vs 2 initial
# Read input data, have 28 walls and 7 creatures
# Status is: ['E68']
# For boost=11, have 1 survivors, vs 2 initial
# Read input data, have 28 walls and 7 creatures
# Status is: ['E8', 'E86']
# For boost=12, have 2 survivors, vs 2 initial
# Test successful for TC=E

# %%
pmachine.run2_completion()
# Out:
# Read input data, have 588 walls and 30 creatures
# Calculated initial elf count=10 for testcode=None
# Read input data, have 588 walls and 30 creatures
# Status is: ['G200', 'G110', 'G200', 'G104', 'G5', 'G35', 'G86', 'G200', 'G200', 'G200', 'G200', 'G200', 'G107', 'G200', 'G200', 'G200', 'G104', 'G200']
# For boost=0, have 0 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['G200', 'G200', 'G200', 'G28', 'G12', 'G176', 'G200', 'G80', 'G200', 'G72', 'G200', 'G200', 'G112', 'G200', 'G200']
# For boost=1, have 0 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['G200', 'G200', 'G55', 'G200', 'G200', 'G160', 'G200', 'G185', 'G200', 'G40', 'G200']
# For boost=2, have 0 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['G32', 'G200', 'G200', 'G20', 'G200', 'G122', 'G98', 'G200', 'G200']
# For boost=3, have 0 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['G200', 'G109', 'G102']
# For boost=4, have 0 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E104', 'E41', 'E179', 'E131']
# For boost=5, have 4 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E20', 'E158', 'E161', 'E155', 'E44', 'E104']
# For boost=6, have 6 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E26', 'E197', 'E137', 'E179', 'E200', 'E86']
# For boost=7, have 6 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E173', 'E146', 'E29', 'E95', 'E167', 'E56', 'E200']
# For boost=8, have 7 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E23', 'E113', 'E200', 'E62', 'E110', 'E176', 'E200', 'E107']
# For boost=9, have 8 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E59', 'E200', 'E155', 'E170', 'E65', 'E200', 'E74', 'E107']
# For boost=10, have 8 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E62', 'E200', 'E167', 'E143', 'E128', 'E191', 'E158', 'E74']
# For boost=11, have 8 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E200', 'E92', 'E137', 'E200', 'E101', 'E110', 'E155', 'E95']
# For boost=12, have 8 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E200', 'E101', 'E158', 'E155', 'E182', 'E80', 'E191', 'E110']
# For boost=13, have 8 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E110', 'E179', 'E122', 'E152', 'E149', 'E188', 'E194', 'E149']
# For boost=14, have 8 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E110', 'E179', 'E122', 'E152', 'E149', 'E188', 'E194', 'E149']
# For boost=15, have 8 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E182', 'E200', 'E119', 'E125', 'E200', 'E149', 'E143', 'E155', 'E86']
# For boost=16, have 9 survivors, vs 10 initial
# Read input data, have 588 walls and 30 creatures
# Status is: ['E200', 'E194', 'E71', 'E197', 'E161', 'E179', 'E116', 'E200', 'E2', 'E125']
# For boost=17, have 10 survivors, vs 10 initial

# %%
pmachine.get_result()
# Out:
# 59245

# %%
#pmachine.run_until(lambda pm: pm.turn_number == 5)
#pmachine.run2_completion()

# %%
#pmachine.print_board()

# %%
health = sum([h for _, h in pmachine.submachine.get_health_status(encode=False)])

# %%
health
# Out:
# 1445

# %%
pmachine.submachine.full_round
# Out:
# 41

# %%
41*1445
# Out:
# 59245

# %%
40*1445
# Out:
# 57800
